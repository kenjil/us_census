# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# must be ran once
import os
ipython_dir = os.getcwd()
os.chdir(ipython_dir+'/..')

# %% [markdown]
# # 1. Predictive variables Statistics

# %%
from census.loader import CensusLoader
# meta data : columns description
from census.meta import cols, cols_desc
learnds = CensusLoader('data/census_income_learn.csv', cols=cols)
learndf = learnds.get_data()

# %% [markdown]
# #### Define variables types and special values

# %%
from census.stats import BasicStatistic
non_valids=[' Do not know', ' ?', ' Not identifiable']
specials=[' Not in universe', ' Not in universe under 1 year old', ' Not in universe or children']

bs = BasicStatistic(non_valids=non_valids, specials=specials)
target = ['TARGET']
# continuous numerical columns
num_cols_standard = ['AGE', 'INSTANCE_WEIGHT']
num_cols_with_zero_treatment = ['WWORKY', 'WPERH','CAP_GAINS', 'CAP_LOSSES', 'STOCK_DIV']
num_cols = num_cols_standard + num_cols_with_zero_treatment
# categorical cols
cat_cols = [col for col in cols if col not in num_cols + target]

# %% [markdown]
# #### Plotting the numeric cols statistics

# %%
# continuous numerical columns
# there's too many values, we will visualize percentage using stepped values
steps_nb = 10
# plot standard numerical columns
for col in num_cols_standard:
    bs.plot_num_stat(learndf[col], learndf['TARGET'], perct_steps=steps_nb, label=cols_desc[col])

# when there's too many zero values, plot them separately
for col in num_cols_with_zero_treatment:
    bs.plot_num_stat(learndf[col], learndf['TARGET'], no_plot_zero=True, perct_steps=steps_nb, perct_zero_aside=True, label=cols_desc[col])

# %% [markdown]
# #### Plotting the classes statistics (special and non valid values appear first in bar lists)

# %%
for col in cat_cols:
    bs.plot_cat_stat(learndf[col], learndf['TARGET'], label=cols_desc[col])
# Out:
# /Users/kenji/Informatique/Python/anaconda/python.app/Contents/lib/python2.7/site-packages/matplotlib/pyplot.py:412: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# # 2. Learning from data

# %% [markdown]
# ## 2.1. Logistic regression

# %%
# cwd must be us_census root
# print os.getcwd()
# %run run_lr.py

# %% [raw]
# ordinateur-de-Kenji:Census kenji$ python run_lr.py
# Loading data from disk...
# Remove columns ['YEAR', 'RESI_REGION', 'RESI_PREV', 'RESI_1YEAR']...
# Transforming variables...
# Convert data to np.array and return
# 	X, y, X_test, y_test, X_cols_name, X_cols_interprets...
#
# ---------------------------------
# TUNING OF HYPERPARAMETERS EXAMPLE
# ---------------------------------
#
# CV hyperparameter to be tuned if needed
# For computationnal time, we work with a reduced dataset.
# 	we take only the first 20000 samples.
# We're using score 'precision'.
# 0.166 (+/-0.006) for {'lr__tol': 0.01, 'lr__class_weight': 'auto', 'lr__C': 0.01}
# 0.244 (+/-0.007) for {'lr__tol': 0.01, 'lr__class_weight': 'auto', 'lr__C': 0.05}
# 0.253 (+/-0.008) for {'lr__tol': 0.01, 'lr__class_weight': 'auto', 'lr__C': 0.075}
# 0.259 (+/-0.012) for {'lr__tol': 0.01, 'lr__class_weight': 'auto', 'lr__C': 0.1}
# 0.276 (+/-0.010) for {'lr__tol': 0.01, 'lr__class_weight': 'auto', 'lr__C': 0.2}
# 0.287 (+/-0.007) for {'lr__tol': 0.01, 'lr__class_weight': 'auto', 'lr__C': 0.3}
# 0.291 (+/-0.004) for {'lr__tol': 0.01, 'lr__class_weight': 'auto', 'lr__C': 0.4}
# 0.293 (+/-0.006) for {'lr__tol': 0.01, 'lr__class_weight': 'auto', 'lr__C': 0.5}
# 0.295 (+/-0.010) for {'lr__tol': 0.01, 'lr__class_weight': 'auto', 'lr__C': 0.6}
# 0.297 (+/-0.010) for {'lr__tol': 0.01, 'lr__class_weight': 'auto', 'lr__C': 0.7}
# 0.299 (+/-0.009) for {'lr__tol': 0.01, 'lr__class_weight': 'auto', 'lr__C': 0.8}
# 0.300 (+/-0.011) for {'lr__tol': 0.01, 'lr__class_weight': 'auto', 'lr__C': 0.9}
# 0.301 (+/-0.011) for {'lr__tol': 0.01, 'lr__class_weight': 'auto', 'lr__C': 1}
#
# Best predictor is
#
# Pipeline(lr=LogisticRegression(C=1, class_weight=auto, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty=l1, random_state=None, tol=0.01),
#      lr__C=1, lr__class_weight=auto, lr__dual=False,
#      lr__fit_intercept=True, lr__intercept_scaling=1, lr__penalty=l1,
#      lr__random_state=None, lr__tol=0.01,
#      my_scaling=MyScaler(num_cols=[0, 5, 6, 1, 2, 3, 4]),
#      my_scaling__num_cols=[0, 5, 6, 1, 2, 3, 4])
# predictor score on test
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.87      0.93     18735
#         1.0       0.31      0.88      0.46      1265
#
# avg / total       0.95      0.87      0.90     20000
#
#
# ----------------------------
# COMPUTATION WITH A PREDICTOR
# ----------------------------
#
# I choose a predictor that seems enough good to see most influential factors.
#
#
#
# WE WORK WITH PREDICTOR :
# Pipeline(lr=LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty=l1, random_state=None, tol=0.001),
#      lr__C=0.1, lr__class_weight=None, lr__dual=False,
#      lr__fit_intercept=True, lr__intercept_scaling=1, lr__penalty=l1,
#      lr__random_state=None, lr__tol=0.001,
#      my_scaling=MyScaler(num_cols=[0, 5, 6, 1, 2, 3, 4]),
#      my_scaling__num_cols=[0, 5, 6, 1, 2, 3, 4])
# fit predictor with C=0.10
#
# predictor score on test
#              precision    recall  f1-score   support
#
#         0.0       0.96      0.99      0.97     93576
#         1.0       0.72      0.35      0.47      6186
#
# avg / total       0.94      0.95      0.94     99762
#
#
# THE MOST INFLUENTIAL FACTS
# Sorted by coef
#
#  - EDU =  Doctorate degree(PhD EdD) : 2.0454
#  - TAX_FILER =  Nonfiler : -1.8245
#  - EDU =  Prof school degree (MD DDS DVM LLB JD) : 1.8036
#  - EDU =  Masters degree(MA MS MEng MEd MSW MBA) : 1.4131
#  - EMPLOYEES_NB = 0 : -1.2817
#  - SEX =  Female : -1.1802
#  - FAMILY_SUM =  Child under 18 never married : -1.0816
#  - OCCUP_D_CODE = 21 : 0.8955
#  - FAMILY_SUM =  Child 18 or older : -0.8379
#  - EDU =  Bachelors degree(BA AB BS) : 0.8082
#  - OCCUP_M_CODE =  Other service : -0.8078
#  - INDUS_D_CODE = 26 : 0.8017
#  - OCCUP_M_CODE =  Handlers equip cleaners etc  : -0.7932
#  - EDU =  10th grade : -0.7747
#  - OCCUP_M_CODE =  Sales : 0.7621
#  - WORKER =  State government : -0.7279
#  - OCCUP_D_CODE = 19 : -0.7134
#  - OCCUP_D_CODE = 2 : 0.6980
#  - INDUS_D_CODE = 13 : 0.6845
#  - EDULW =  College or university : -0.6838
#
# THE MOST INFLUENTIAL FACTS
# Sorted by max coef within each group
#
#  - EDU =  Doctorate degree(PhD EdD) : 2.0454
#  - EDU =  Prof school degree (MD DDS DVM LLB JD) : 1.8036
#  - EDU =  Masters degree(MA MS MEng MEd MSW MBA) : 1.4131
#  - EDU =  Bachelors degree(BA AB BS) : 0.8082
#  - EDU =  10th grade : -0.7747
#  - EDU =  9th grade : -0.6305
#  - EDU =  7th and 8th grade : -0.6183
#  - EDU =  11th grade : -0.6096
#  - EDU =  5th or 6th grade : -0.5799
#  - TAX_FILER =  Nonfiler : -1.8245
#  - EMPLOYEES_NB = 0 : -1.2817
#  - EMPLOYEES_NB = 1 : -0.5177
#  - EMPLOYEES_NB = 6 : 0.4186
#  - SEX =  Female : -1.1802
#  - FAMILY_SUM =  Child under 18 never married : -1.0816
#  - FAMILY_SUM =  Child 18 or older : -0.8379
#  - FAMILY_SUM =  Other relative of householder : -0.4427
#  - OCCUP_D_CODE = 21 : 0.8955
#  - OCCUP_D_CODE = 19 : -0.7134
#  - OCCUP_D_CODE = 2 : 0.6980
#  - OCCUP_D_CODE = 11 : 0.6672
#  - OCCUP_D_CODE = 7 : 0.6454
#  - OCCUP_D_CODE = 44 : -0.5391
#  - OCCUP_D_CODE = 12 : -0.5021
#  - OCCUP_D_CODE = 10 : -0.4614
#  - OCCUP_D_CODE = 15 : 0.4215
#  - OCCUP_D_CODE = 4 : 0.3873
#  - OCCUP_D_CODE = 31 : -0.3733
#  - OCCUP_D_CODE = 8 : 0.3163
#  - OCCUP_M_CODE =  Other service : -0.8078
#  - OCCUP_M_CODE =  Handlers equip cleaners etc  : -0.7932
#  - OCCUP_M_CODE =  Sales : 0.7621
#  - OCCUP_M_CODE =  Adm support including clerical : -0.6589
#  - OCCUP_M_CODE =  Machine operators assmblrs & inspctrs : -0.6462
#  - OCCUP_M_CODE =  Professional specialty : 0.6031
#  - OCCUP_M_CODE =  Executive admin and managerial : 0.4732
#  - INDUS_D_CODE = 26 : 0.8017
#  - INDUS_D_CODE = 13 : 0.6845
#  - INDUS_D_CODE = 25 : 0.5310
#  - INDUS_D_CODE = 44 : -0.4249
#  - INDUS_D_CODE = 3 : 0.3868
#  - INDUS_D_CODE = 6 : -0.3675
#  - INDUS_D_CODE = 23 : 0.3438
#  - INDUS_D_CODE = 19 : -0.3095
#  - WORKER =  State government : -0.7279
#  - WORKER =  Self-employed-incorporated : 0.6751
#  - WORKER =  Local government : -0.3725
#  - WORKER =  Not in universe : -0.3445
#  - EDULW =  College or university : -0.6838
#  - SELF_EMPLOYED = 2 : -0.6575
#  - SELF_EMPLOYED = 0 : -0.4935
#  - MARIT =  Never married : -0.6082
#  - ORIG_SELF =  United-States : -0.6000
#  - WORK_TIME =  Children or Armed Forces : -0.5737
#  - INDUS_M_CODE =  Retail trade : -0.5289
#  - INDUS_M_CODE =  Communications : 0.3840
#  - INDUS_M_CODE =  Utilities and sanitary services : 0.3837
#  - CITIZEN =  Native- Born in the United States : 0.4680
#  - CITIZEN =  Foreign born- Not a citizen of U S  : -0.4126
#  - VETERAN_Q =  Not in universe : -0.4614
#  - CAP_GAINS columns : 0.4214
#  - MIG_MSA =  NonMSA to nonMSA : -0.3636
#  - FAMILY_STAT =  Child <18 never marr not in subfamily : -0.3513
#  - STOCK_DIV columns : 0.3318
#  - LAB_UNION =  No : -0.3098

# %% [markdown]
# ## 2.2.1. Random forest on raw data

# %%
# %run run_rf_raw.py

# %% [markdown]
# #### Ipython is too slow..
# Terminal output :

# %% [raw]
# ordinateur-de-Kenji:Census kenji$ python run_rf_raw.py
#
# Loading data from disk and transform it with :
#   - no columns removed
#   - categorical variables are label so that the corresponding numerical values are growing
#   with the proportion of +50.000$
#
# Loading data from disk...
# Transforming variables...
# Convert data to np.array and return
# 	X, y, X_test, y_test, X_cols_name, X_cols_interprets...
#
# ---------------------------------
# TUNING OF HYPERPARAMETERS EXAMPLE
# ---------------------------------
# must be ran on many more samples to be really valuable.
#
# CV hyperparameter to be tuned if needed
# For computationnal time, we work with a reduced dataset.
# 	we take only the first 2000 samples.
# We're using score 'precision'.
#
# 0.740 (+/-0.293) for {'rf__n_estimators': 10}
# 0.700 (+/-0.389) for {'rf__n_estimators': 25}
# 0.833 (+/-0.422) for {'rf__n_estimators': 50}
# 0.800 (+/-0.533) for {'rf__n_estimators': 100}
# 0.833 (+/-0.422) for {'rf__n_estimators': 250}
# 0.800 (+/-0.389) for {'rf__n_estimators': 500}
# 0.793 (+/-0.387) for {'rf__n_estimators': 1000}
#
# Best predictor is
#
# Pipeline(my_scaling=MyScaler(num_cols=[0, 24, 39, 5, 16, 17, 18]),
#      my_scaling__num_cols=[0, 24, 39, 5, 16, 17, 18],
#      rf=RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion=gini, max_depth=None, max_features=auto,
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             n_estimators=50, n_jobs=-1, oob_score=False, random_state=None,
#             verbose=0),
#      rf__bootstrap=True, rf__compute_importances=None, rf__criterion=gini,
#      rf__max_depth=None, rf__max_features=auto, rf__min_density=None,
#      rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=50,
#      rf__n_jobs=-1, rf__oob_score=False, rf__random_state=None,
#      rf__verbose=0)
#
#
# ----------------------------
# COMPUTATION WITH A PREDICTOR
# ----------------------------
#
# I choose the predictor with full grown tree and 100 trees.
#
#
#
# WE WORK WITH PREDICTOR :
# Pipeline(my_scaling=MyScaler(num_cols=[0, 24, 39, 5, 16, 17, 18]),
#      my_scaling__num_cols=[0, 24, 39, 5, 16, 17, 18],
#      rf=RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion=gini, max_depth=None, max_features=auto,
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             n_estimators=100, n_jobs=-1, oob_score=False,
#             random_state=None, verbose=0),
#      rf__bootstrap=True, rf__compute_importances=None, rf__criterion=gini,
#      rf__max_depth=None, rf__max_features=auto, rf__min_density=None,
#      rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100,
#      rf__n_jobs=-1, rf__oob_score=False, rf__random_state=None,
#      rf__verbose=0)
# fit predictor with hyperparameter {'oob_score': False, 'n_jobs': -1, 'verbose': 0, 'min_density': None, 'compute_importances': None, 'bootstrap': True, 'min_samples_leaf': 1, 'n_estimators': 100, 'min_samples_split': 2, 'random_state': None, 'criterion': 'gini', 'max_features': 'auto', 'max_depth': None}
# predictor score on test
#              precision    recall  f1-score   support
#
#         0.0       0.96      0.99      0.98     93576
#         1.0       0.76      0.40      0.53      6186
#
# avg / total       0.95      0.95      0.95     99762
#
#
# THE MOST INFLUENTIAL FACTS
# Sorted by coef
#
#  - INSTANCE_WEIGHT columns : 0.0976
#  - OCCUP_D_CODE columns : 0.0938
#  - AGE columns : 0.0931
#  - STOCK_DIV columns : 0.0872
#  - CAP_GAINS columns : 0.0859
#  - INDUS_D_CODE columns : 0.0532
#  - EDU columns : 0.0505
#  - EMPLOYEES_NB columns : 0.0406
#  - WWORKY columns : 0.0365
#  - INDUS_M_CODE columns : 0.0360
#  - SEX columns : 0.0323
#  - OCCUP_M_CODE columns : 0.0315
#  - CAP_LOSSES columns : 0.0269
#  - WORKER columns : 0.0239
#  - TAX_FILER columns : 0.0175
#  - FAMILY_STAT columns : 0.0169
#  - MARIT columns : 0.0156
#  - ORIG_FATHER columns : 0.0133
#  - ORIG_MOTHER columns : 0.0129
#  - SELF_EMPLOYED columns : 0.0126
#
# THE MOST INFLUENTIAL FACTS
# Sorted by max coef within each group
#
#  - INSTANCE_WEIGHT columns : 0.0976
#  - OCCUP_D_CODE columns : 0.0938
#  - AGE columns : 0.0931
#  - STOCK_DIV columns : 0.0872
#  - CAP_GAINS columns : 0.0859
#  - INDUS_D_CODE columns : 0.0532
#  - EDU columns : 0.0505
#  - EMPLOYEES_NB columns : 0.0406
#  - WWORKY columns : 0.0365
#  - INDUS_M_CODE columns : 0.0360
#  - SEX columns : 0.0323
#  - OCCUP_M_CODE columns : 0.0315
#  - CAP_LOSSES columns : 0.0269
#  - WORKER columns : 0.0239
#  - TAX_FILER columns : 0.0175
#  - FAMILY_STAT columns : 0.0169
#  - MARIT columns : 0.0156
#  - ORIG_FATHER columns : 0.0133
#  - ORIG_MOTHER columns : 0.0129
#  - SELF_EMPLOYED columns : 0.0126
#  - LAB_UNION columns : 0.0121
#  - WPERH columns : 0.0117
#  - FAMILY_SUM columns : 0.0111
#  - WORK_TIME columns : 0.0104
#  - RACE columns : 0.0090
#  - ORIG_SELF columns : 0.0072
#  - HISP columns : 0.0067
#  - MIG_REGION columns : 0.0060
#  - MIG_MOVE columns : 0.0060
#  - MIG_MSA columns : 0.0060
#  - MIG_SUNBELT columns : 0.0059
#  - CITIZEN columns : 0.0054
#  - RESI_1YEAR columns : 0.0053
#  - RESI_PREV columns : 0.0048
#  - YEAR columns : 0.0039
#  - RESI_REGION columns : 0.0034
#  - UNEMP_REASON columns : 0.0022
#  - VETERAN_Q columns : 0.0020
#  - VETERAN_BEN columns : 0.0019
#  - EDULW columns : 0.0007
#  - UNDER_18_NB columns : 0.0004

# %% [markdown]
# ## 2.2.2. Random forest on dummified data

# %%
# %run run_rf_dumm.py

# %% [markdown]
# #### Terminal output :

# %% [raw]
# ordinateur-de-Kenji:Census kenji$ python run_rf_dumm.py
#
# Loading data from disk and transform it with :
#     - dummification of categorical variables
#     - removing of some columns (see below)
#     - add boolean variables when numerical inputs code in fact two variables
#     eg: WWORKY weeks worked per year : have instance worked in term of weeks ?
#                                        if yes, how much ?
#
# Loading data from disk...
# Remove columns ['YEAR', 'RESI_REGION', 'RESI_PREV', 'RESI_1YEAR']...
# Transforming variables...
# Convert data to np.array and return
# 	X, y, X_test, y_test, X_cols_name, X_cols_interprets...
#
# ---------------------------------
# TUNING OF HYPERPARAMETERS EXAMPLE
# ---------------------------------
#
# CV hyperparameter to be tuned if needed
# For computationnal time, we work with a reduced dataset.
# 	we take only the first 2000 samples.
# We're using score 'precision'.
#
# 0.500 (+/-0.894) for {'rf__n_estimators': 10}
# 0.700 (+/-0.800) for {'rf__n_estimators': 25}
# 0.667 (+/-0.843) for {'rf__n_estimators': 50}
# 0.600 (+/-0.777) for {'rf__n_estimators': 100}
# 0.500 (+/-0.894) for {'rf__n_estimators': 250}
# 0.667 (+/-0.843) for {'rf__n_estimators': 500}
# 0.667 (+/-0.843) for {'rf__n_estimators': 1000}
#
# Best predictor is
#
# Pipeline(my_scaling=MyScaler(num_cols=[0, 5, 6, 1, 2, 3, 4]),
#      my_scaling__num_cols=[0, 5, 6, 1, 2, 3, 4],
#      rf=RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion=gini, max_depth=None, max_features=auto,
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             n_estimators=25, n_jobs=-1, oob_score=False, random_state=None,
#             verbose=0),
#      rf__bootstrap=True, rf__compute_importances=None, rf__criterion=gini,
#      rf__max_depth=None, rf__max_features=auto, rf__min_density=None,
#      rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=25,
#      rf__n_jobs=-1, rf__oob_score=False, rf__random_state=None,
#      rf__verbose=0)
#
#
#
# ----------------------------
# COMPUTATION WITH A PREDICTOR
# ----------------------------
#
# I choose the predictor with 100 fully grown trees.
#
#
#
# WE WORK WITH PREDICTOR :
# Pipeline(my_scaling=MyScaler(num_cols=[0, 5, 6, 1, 2, 3, 4]),
#      my_scaling__num_cols=[0, 5, 6, 1, 2, 3, 4],
#      rf=RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion=gini, max_depth=None, max_features=auto,
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             n_estimators=100, n_jobs=-1, oob_score=False,
#             random_state=None, verbose=0),
#      rf__bootstrap=True, rf__compute_importances=None, rf__criterion=gini,
#      rf__max_depth=None, rf__max_features=auto, rf__min_density=None,
#      rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100,
#      rf__n_jobs=-1, rf__oob_score=False, rf__random_state=None,
#      rf__verbose=0)
# fit predictor with hyperparameter {'oob_score': False, 'n_jobs': -1, 'verbose': 0, 'min_density': None, 'compute_importances': None, 'bootstrap': True, 'min_samples_leaf': 1, 'n_estimators': 100, 'min_samples_split': 2, 'random_state': None, 'criterion': 'gini', 'max_features': 'auto', 'max_depth': None}
# predictor score on test
#              precision    recall  f1-score   support
#
#         0.0       0.96      0.99      0.98     93576
#         1.0       0.76      0.39      0.51      6186
#
# avg / total       0.95      0.95      0.95     99762
#
#
# THE MOST INFLUENTIAL FACTS
# Sorted by coef
#
#  - INSTANCE_WEIGHT columns : 0.0678
#  - AGE columns : 0.0667
#  - CAP_GAINS columns : 0.0560
#  - STOCK_DIV columns : 0.0556
#  - WWORKY columns : 0.0238
#  - STOCK_DIV_eq_0 columns : 0.0231
#  - OCCUP_M_CODE =  Executive admin and managerial : 0.0162
#  - SEX =  Male : 0.0156
#  - SEX =  Female : 0.0154
#  - CAP_LOSSES columns : 0.0144
#  - EDU =  Masters degree(MA MS MEng MEd MSW MBA) : 0.0142
#  - EDU =  Bachelors degree(BA AB BS) : 0.0133
#  - OCCUP_D_CODE = 2 : 0.0128
#  - EMPLOYEES_NB = 6 : 0.0126
#  - OCCUP_M_CODE =  Professional specialty : 0.0124
#  - CAP_GAINS_eq_0 columns : 0.0123
#  - EDU =  Prof school degree (MD DDS DVM LLB JD) : 0.0104
#  - EDU =  High school graduate : 0.0103
#  - FAMILY_STAT =  Householder : 0.0092
#  - FAMILY_SUM =  Householder : 0.0085
#
# THE MOST INFLUENTIAL FACTS
# Sorted by max coef within each group
#
#  - INSTANCE_WEIGHT columns : 0.0678
#  - AGE columns : 0.0667
#  - CAP_GAINS columns : 0.0560
#  - STOCK_DIV columns : 0.0556
#  - WWORKY columns : 0.0238
#  - STOCK_DIV_eq_0 columns : 0.0231
#  - OCCUP_M_CODE =  Executive admin and managerial : 0.0162
#  - OCCUP_M_CODE =  Professional specialty : 0.0124
#  - OCCUP_M_CODE =  Not in universe : 0.0050
#  - OCCUP_M_CODE =  Sales : 0.0036
#  - OCCUP_M_CODE =  Adm support including clerical : 0.0035
#  - OCCUP_M_CODE =  Precision production craft & repair : 0.0029
#  - OCCUP_M_CODE =  Other service : 0.0020
#  - OCCUP_M_CODE =  Technicians and related support : 0.0017
#  - OCCUP_M_CODE =  Machine operators assmblrs & inspctrs : 0.0015
#  - OCCUP_M_CODE =  Transportation and material moving : 0.0015
#  - OCCUP_M_CODE =  Protective services : 0.0010
#  - OCCUP_M_CODE =  Handlers equip cleaners etc  : 0.0009
#  - OCCUP_M_CODE =  Farming forestry and fishing : 0.0006
#  - OCCUP_M_CODE =  Armed Forces : 0.0001
#  - OCCUP_M_CODE =  Private household services : 0.0000
#  - SEX =  Male : 0.0156
#  - SEX =  Female : 0.0154
#  - CAP_LOSSES columns : 0.0144
#  - EDU =  Masters degree(MA MS MEng MEd MSW MBA) : 0.0142
#  - EDU =  Bachelors degree(BA AB BS) : 0.0133
#  - EDU =  Prof school degree (MD DDS DVM LLB JD) : 0.0104
#  - EDU =  High school graduate : 0.0103
#  - EDU =  Some college but no degree : 0.0081
#  - EDU =  Doctorate degree(PhD EdD) : 0.0074
#  - EDU =  Associates degree-occup /vocational : 0.0034
#  - EDU =  Associates degree-academic program : 0.0032
#  - EDU =  10th grade : 0.0010
#  - EDU =  11th grade : 0.0010
#  - EDU =  7th and 8th grade : 0.0009
#  - EDU =  9th grade : 0.0005
#  - EDU =  12th grade no diploma : 0.0004
#  - EDU =  5th or 6th grade : 0.0003
#  - EDU =  1st 2nd 3rd or 4th grade : 0.0002
#  - EDU =  Children : 0.0001
#  - EDU =  Less than 1st grade : 0.0000
#  - OCCUP_D_CODE = 2 : 0.0128
#  - OCCUP_D_CODE = 4 : 0.0059
#  - OCCUP_D_CODE = 7 : 0.0053
#  - OCCUP_D_CODE = 11 : 0.0052
#  - OCCUP_D_CODE = 12 : 0.0032
#  - OCCUP_D_CODE = 0 : 0.0027
#  - OCCUP_D_CODE = 16 : 0.0026
#  - OCCUP_D_CODE = 3 : 0.0026
#  - OCCUP_D_CODE = 17 : 0.0025
#  - OCCUP_D_CODE = 5 : 0.0023
#  - OCCUP_D_CODE = 10 : 0.0021
#  - OCCUP_D_CODE = 33 : 0.0020
#  - OCCUP_D_CODE = 8 : 0.0020
#  - OCCUP_D_CODE = 26 : 0.0020
#  - OCCUP_D_CODE = 18 : 0.0018
#  - OCCUP_D_CODE = 35 : 0.0018
#  - OCCUP_D_CODE = 34 : 0.0016
#  - OCCUP_D_CODE = 15 : 0.0014
#  - OCCUP_D_CODE = 38 : 0.0012
#  - OCCUP_D_CODE = 28 : 0.0011
#  - OCCUP_D_CODE = 19 : 0.0011
#  - OCCUP_D_CODE = 9 : 0.0010
#  - OCCUP_D_CODE = 6 : 0.0010
#  - OCCUP_D_CODE = 36 : 0.0010
#  - OCCUP_D_CODE = 39 : 0.0010
#  - OCCUP_D_CODE = 14 : 0.0009
#  - OCCUP_D_CODE = 21 : 0.0008
#  - OCCUP_D_CODE = 37 : 0.0007
#  - OCCUP_D_CODE = 1 : 0.0007
#  - OCCUP_D_CODE = 23 : 0.0007
#  - OCCUP_D_CODE = 13 : 0.0006
#  - OCCUP_D_CODE = 43 : 0.0005
#  - OCCUP_D_CODE = 24 : 0.0005
#  - OCCUP_D_CODE = 31 : 0.0004
#  - OCCUP_D_CODE = 42 : 0.0004
#  - OCCUP_D_CODE = 22 : 0.0004
#  - OCCUP_D_CODE = 32 : 0.0004
#  - OCCUP_D_CODE = 25 : 0.0004
#  - OCCUP_D_CODE = 29 : 0.0003
#  - OCCUP_D_CODE = 41 : 0.0003
#  - OCCUP_D_CODE = 44 : 0.0002
#  - OCCUP_D_CODE = 30 : 0.0002
#  - OCCUP_D_CODE = 40 : 0.0002
#  - OCCUP_D_CODE = 45 : 0.0002
#  - OCCUP_D_CODE = 20 : 0.0001
#  - OCCUP_D_CODE = 46 : 0.0001
#  - OCCUP_D_CODE = 27 : 0.0000
#  - EMPLOYEES_NB = 6 : 0.0126
#  - EMPLOYEES_NB = 1 : 0.0071
#  - EMPLOYEES_NB = 0 : 0.0070
#  - EMPLOYEES_NB = 4 : 0.0061
#  - EMPLOYEES_NB = 3 : 0.0058
#  - EMPLOYEES_NB = 2 : 0.0045
#  - EMPLOYEES_NB = 5 : 0.0038
#  - CAP_GAINS_eq_0 columns : 0.0123
#  - FAMILY_STAT =  Householder : 0.0092
#  - FAMILY_STAT =  Spouse of householder : 0.0033
#  - FAMILY_STAT =  Nonfamily householder : 0.0027
#  - FAMILY_STAT =  Secondary individual : 0.0009
